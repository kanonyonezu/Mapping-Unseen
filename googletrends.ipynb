# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
words = pd.read_csv('searched_with_top-searches_Worldwide_20040101-0900_20260811-2215.csv')

# %%
timeseries = pd.read_csv("time_series_Worldwide_20040101-0900_20260811-2214.csv", parse_dates=["Time"])
timeseries = timeseries.set_index("Time")

plt.figure(figsize=(12, 6))
plt.plot(timeseries.index, timeseries["星空ツアー"])
plt.show()

# %%
words.index = range(1, len(words) + 1)

# %%
words
# Out:
#                     query  search interest increase percent
# 1                      星空              100               5%
# 2                  星空 ツアー              100               0%
# 3                阿智 村 ツアー               20               4%
# 4                 ナイト ツアー               20              -3%
# 5              星空 ナイト ツアー               20               5%
# 6                 阿智 村 星空               19               3%
# 7             星空 ツアー 阿智 村               19               3%
# 8             阿智 村 星空 ツアー               19              -1%
# 9                    阿智 村               18              -2%
# 10                   石垣 島               10              20%
# 11            石垣 島 星空 ツアー               10               5%
# 12                石垣 島 星空                9               3%
# 13               石垣 島 ツアー                9               0%
# 14              星空 ツアー 長野                9               7%
# 15                  長野 星空                9               0%
# ...
